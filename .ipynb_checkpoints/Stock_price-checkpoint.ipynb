# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("AAPL.csv")

# %%
cl = df["close"]

# %%
plt.plot(cl)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
sc = MinMaxScaler(feature_range = (0,1))
cl = sc.fit_transform(np.array(cl).reshape(-1,1))

# %%
train_data = cl[0:int(len(cl)*0.65),:]
test_data = cl[int(len(cl)*0.65):len(cl),:]

# %%
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])

    return np.array(dataX), np.array(dataY)

# %% [markdown]
# ## Raw model training

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
import math
from sklearn.metrics import mean_squared_error

# %%
rmse = []
for n in range (10,260,20):
    time_step = n
    X_train, y_train = create_dataset(train_data, time_step)
    X_test, y_test = create_dataset(test_data, time_step)
    
    # reshape input to be [samples, time steps, features] which is required for LSTM
    X_train = X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
    X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)
    
    model=Sequential()
    model.add(LSTM(50,return_sequences=True,input_shape=(time_step,1)))
    model.add(LSTM(50,return_sequences=True))
    model.add(LSTM(50))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error',optimizer='adam')
    
    model.fit(X_train,y_train, validation_data=(X_test,y_test), epochs=3, batch_size=64, verbose=0)
    test_predict = model.predict(X_test)
    test_predict1 = sc.inverse_transform(test_predict)
    
    # rmse calc
    rmse.append(math.sqrt(mean_squared_error(sc.inverse_transform(y_test.reshape(y_test.shape[0],1)),sc.inverse_transform(test_predict))))
# Out:
# ...
# 6/6 [==============================] - 2s 83ms/step

# %%
plt.plot(rmse)

# %%
rmse2 = []
for n in range (2,10):
    time_step = n
    X_train, y_train = create_dataset(train_data, time_step)
    X_test, y_test = create_dataset(test_data, time_step)
    
    # reshape input to be [samples, time steps, features] which is required for LSTM
    X_train = X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
    X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)
    
    model=Sequential()
    model.add(LSTM(50,return_sequences=True,input_shape=(time_step,1)))
    model.add(LSTM(50,return_sequences=True))
    model.add(LSTM(50))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error',optimizer='adam')
    
    model.fit(X_train,y_train, validation_data=(X_test,y_test), epochs=3, batch_size=64, verbose=0)
    test_predict = model.predict(X_test)
    test_predict1 = sc.inverse_transform(test_predict)
    
    # rmse calc
    rmse2.append(math.sqrt(mean_squared_error(sc.inverse_transform(y_test.reshape(y_test.shape[0],1)),sc.inverse_transform(test_predict))))
# Out:
# ...
# 14/14 [==============================] - 1s 5ms/step

# %%
plt.plot(rmse2)

# %%
# set time_step to 5 for min error and try tweaking model parameters

time_step = 5
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# reshape input to be [samples, time steps, features] which is required for LSTM
X_train = X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(time_step,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

model.fit(X_train,y_train, validation_data=(X_test,y_test), epochs=3, batch_size=64, verbose=0)
test_predict = model.predict(X_test)
test_predict1 = sc.inverse_transform(test_predict)

# rmse calc
rmse_min = math.sqrt(mean_squared_error(sc.inverse_transform(y_test.reshape(y_test.shape[0],1)),sc.inverse_transform(test_predict)))
# Out:
# 14/14 [==============================] - 3s 6ms/step

# %%
(rmse_min)
# Out:
# 8.551166777788758

# %%
from sklearn.metrics import r2_score

# %%
y_test_inverse = sc.inverse_transform(y_test.reshape(y_test.shape[0], 1))
r2 = r2_score(y_test_inverse, test_predict1)
print(f'R² Score: {r2}')
# Out:
# R² Score: 0.9673530330909063

# %% [markdown]
# ## Grid Search

# %%
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import GridSearchCV
from keras.models import Sequential
from keras.layers import LSTM, Dense
from keras.optimizers import Adam

def create_model(optimizer='adam', neurons=50):
    model = Sequential()
    model.add(LSTM(neurons, return_sequences=True, input_shape=(time_step, 1)))
    model.add(LSTM(neurons, return_sequences=True))
    model.add(LSTM(neurons))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer=optimizer)
    return model

# %%
model = KerasRegressor(build_fn=create_model, verbose=0)
# Out:
# C:\Users\Nikshay Jain\AppData\Local\Temp\ipykernel_1852\3022883795.py:1: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasRegressor(build_fn=create_model, verbose=0)

# %%
param_grid = {
    'batch_size': [32, 64, 128],
    'epochs': [1,3],
    'optimizer': ['adam', 'rmsprop'],
    'neurons': [5, 10, 50, 100]
}

# %%
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)
grid_result = grid.fit(X_train, y_train)

# %%
print(f"Best: {grid_result.best_score_} using {grid_result.best_params_}")
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print(f"{mean} ({stdev}) with: {param}")
# Out:
# Best: -0.0001377061562379822 using {'batch_size': 32, 'epochs': 100, 'neurons': 100, 'optimizer': 'adam'}
# -0.0004104319280789544 (0.00024937088910307307) with: {'batch_size': 32, 'epochs': 10, 'neurons': 50, 'optimizer': 'adam'}
# -0.000698395170426617 (0.0002579347613916258) with: {'batch_size': 32, 'epochs': 10, 'neurons': 50, 'optimizer': 'rmsprop'}
# -0.0003511499720237528 (0.00014783753088414844) with: {'batch_size': 32, 'epochs': 10, 'neurons': 100, 'optimizer': 'adam'}
# -0.0011467746808193624 (0.00034342385168237597) with: {'batch_size': 32, 'epochs': 10, 'neurons': 100, 'optimizer': 'rmsprop'}
# -0.00035554790035045397 (0.00027261273988722276) with: {'batch_size': 32, 'epochs': 10, 'neurons': 150, 'optimizer': 'adam'}
# -0.00029340801120270044 (0.0001555428131569523) with: {'batch_size': 32, 'epochs': 10, 'neurons': 150, 'optimizer': 'rmsprop'}
# -0.0002987724947161041 (0.0001440763416876512) with: {'batch_size': 32, 'epochs': 50, 'neurons': 50, 'optimizer': 'adam'}
# ...

# %% [markdown]
# ## Hyperband

# %%
import keras_tuner as kt
from keras.models import Sequential
from keras.layers import LSTM, Dense

def build_model(hp):
    model = Sequential()
    model.add(LSTM(units=hp.Int('units', min_value=32, max_value=256, step=32),
                   return_sequences=True, input_shape=(time_step, 1)))
    model.add(LSTM(units=hp.Int('units', min_value=32, max_value=256, step=32), return_sequences=True))
    model.add(LSTM(units=hp.Int('units', min_value=32, max_value=256, step=32)))
    model.add(Dense(1))
    
    model.compile(optimizer=hp.Choice('optimizer', ['adam', 'rmsprop']),
                  loss='mean_squared_error')
    
    return model

tuner = kt.Hyperband(build_model,
                     objective='val_loss',
                     max_epochs=10,
                     factor=3,
                     directory='my_dir',
                     project_name='stock_lstm')

tuner.search(X_train, y_train, epochs=3, validation_data=(X_test, y_test))
# Out:
# Trial 15 Complete [00h 00m 19s]
# val_loss: 0.006570317316800356
#
# Best val_loss So Far: 0.0011730196420103312
# Total elapsed time: 00h 05m 35s

# %%
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
model = tuner.hypermodel.build(best_hps)
model.fit(X_train, y_train, epochs=3, validation_data=(X_test, y_test))
# Out:
# Epoch 1/3
# 26/26 [==============================] - 20s 287ms/step - loss: 0.0108 - val_loss: 0.0025
# Epoch 2/3
# 26/26 [==============================] - 4s 161ms/step - loss: 5.5173e-04 - val_loss: 0.0028
# Epoch 3/3
# 26/26 [==============================] - 5s 181ms/step - loss: 2.7491e-04 - val_loss: 0.0011

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_3 (LSTM)               (None, 5, 256)            264192
#
#  lstm_4 (LSTM)               (None, 5, 256)            525312
#
#  lstm_5 (LSTM)               (None, 256)               525312
#
#  dense_1 (Dense)             (None, 1)                 257
#
# ...
# Total params: 1,315,073
# Trainable params: 1,315,073
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.save('optimized_lstm_model.h5')

# %%
import json

# Save best hyperparameters to a file
best_hyperparameters = {
    'units': best_hps.get('units'),
    'optimizer': best_hps.get('optimizer'),
#     'batch_size': best_hps.get('batch_size'),
#     'epochs': best_hps.get('epochs')
}

with open('best_hyperparameters.json', 'w') as f:
    json.dump(best_hyperparameters, f)

# %%
test_predict = model.predict(X_test)
test_predict1 = sc.inverse_transform(test_predict)
# Out:
# 14/14 [==============================] - 3s 35ms/step

# %%
test_predict1
# Out:
# array([[217.34702],
#        [218.4604 ],
#        [220.0906 ],
#        [222.27649],
#        [224.59557],
#        [226.83336],
#        [228.01067],
#        [228.19122],
#        [226.83597],
#        [224.8079 ],
#        [222.98093],
#        [222.624  ],
#        [223.14989],
#        [224.69275],
#        [223.96587],
#        [223.84044],
#        [221.48328],
#        [219.69818],
#        [220.06331],
#        [220.55676],
#        [221.19312],
#        [221.58183],
#        [223.28502],
#        [224.3921 ],
#        [225.54056],
#        [228.0123 ],
#        [229.27231],
#        [230.20844],
#        [230.30661],
#        [229.41957],
#        [226.7453 ],
#        [224.54265],
#        [223.19336],
#        [221.62204],
#        [218.79988],
#        [219.88449],
#        [221.72914],
#        [220.7819 ],
#        [221.53456],
#        [220.73442],
#        [220.06633],
#        [221.24426],
#        [221.10011],
#        [219.97037],
#        [217.52074],
# ...

# %%
train_predict = model.predict(X_train)
train_predict1 = sc.inverse_transform(train_predict)
# Out:
# 26/26 [==============================] - 1s 38ms/step

# %%
# rmse calc
rmse_min = math.sqrt(mean_squared_error(sc.inverse_transform(y_test.reshape(y_test.shape[0],1)),sc.inverse_transform(test_predict)))

# %%
rmse_min
# Out:
# 8.028218424943066

# %%
y_test1 = sc.inverse_transform(y_test.reshape(y_test.shape[0],1))
np.mean((test_predict1 - y_test1) / y_test1)*100
# Out:
# 0.2941686219719875

# %%
y_test_inverse = sc.inverse_transform(y_test.reshape(y_test.shape[0], 1))
r2 = r2_score(y_test_inverse, test_predict1)
print(f'R² Score: {r2}')
# Out:
# R² Score: 0.9712239986460577

# %%
sc.inverse_transform(cl)
# Out:
# array([[132.045],
#        [131.78 ],
#        [130.28 ],
#        ...,
#        [319.23 ],
#        [316.85 ],
#        [318.89 ]])

# %%
# shift train predictions for plotting
look_back=5
trainPredictPlot = np.empty_like(sc.inverse_transform(cl))
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict1)+look_back, :] = train_predict1

# shift test predictions for plotting
testPredictPlot = np.empty_like(sc.inverse_transform(cl))
testPredictPlot[:, :] = np.nan
testPredictPlot[len(train_predict1)+(look_back*2)+1:len(cl)-1, :] = test_predict1

# plot baseline and predictions
plt.plot(sc.inverse_transform(cl))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
test_data.shape
# Out:
# (441, 1)

# %%
# Out:
# (1, 441)

# %%
x_input = test_data.reshape(1, -1)
x_input = x_input.flatten()

# Convert x_input to list
temp_input = list(x_input)

lst_output = []
n_steps = 5
i = 0

while(i < 30):
    if len(temp_input) > n_steps:
        # Use the last n_steps values
        x_input = np.array(temp_input[-n_steps:])
        
        # Reshape for LSTM model input
        x_input = x_input.reshape((1, n_steps, 1))
        
        # Predict next value
        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i, yhat))
        
        # Add the predicted value to temp_input
        temp_input.extend(yhat[0].tolist())
        lst_output.extend(yhat.tolist())
        
        i += 1
        
    else:
        # When the temp_input size is smaller than n_steps (initial step)
        x_input = np.array(temp_input).reshape((1, n_steps, 1))
        yhat = model.predict(x_input, verbose=0)
        print(yhat[0])
        
        # Add the predicted value to temp_input
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        
        lst_output.extend(yhat.tolist())
        i += 1

# print(lst_output)
# Out:
# 0 day output [[0.9564678]]
# 1 day output [[0.95957136]]
# 2 day output [[0.96606356]]
# 3 day output [[0.96414286]]
# 4 day output [[0.9659934]]
# 5 day output [[0.9652585]]
# 6 day output [[0.96784043]]
# 7 day output [[0.969848]]
# 8 day output [[0.9700038]]
# 9 day output [[0.97118956]]
# 10 day output [[0.9721402]]
# 11 day output [[0.97375554]]
# 12 day output [[0.97489375]]
# 13 day output [[0.9757203]]
# 14 day output [[0.9768769]]
# 15 day output [[0.9780189]]
# 16 day output [[0.9792245]]
# 17 day output [[0.980258]]
# 18 day output [[0.98127645]]
# 19 day output [[0.9823882]]
# 20 day output [[0.9834805]]
# 21 day output [[0.9845544]]
# 22 day output [[0.98558336]]
# 23 day output [[0.98662454]]
# 24 day output [[0.9876816]]
# 25 day output [[0.9887205]]
# 26 day output [[0.98974466]]
# 27 day output [[0.99075776]]
# 28 day output [[0.991773]]
# 29 day output [[0.99278337]]

# %%
day_new=np.arange(1,6)
day_pred=np.arange(6,36)

# %%
len(day_pred)
# Out:
# 30

# %%
plt.plot(day_new,sc.inverse_transform(cl[1253:]))
plt.plot(day_pred,sc.inverse_transform(lst_output))

# %%
sc.inverse_transform(lst_output)
# Out:
# array([[316.88896484],
#        [317.62407269],
#        [319.1618146 ],
#        [318.70687758],
#        [319.14519776],
#        [318.97112336],
#        [319.58268499],
#        [320.05819187],
#        [320.09509621],
#        [320.37595883],
#        [320.60112611],
#        [320.98373684],
#        [321.25333333],
#        [321.44910703],
#        [321.72306597],
#        [321.99355189],
#        [322.27911579],
#        [322.52390703],
#        [322.76514055],
#        [323.02846867],
#        [323.28719433],
#        [323.54155755],
#        [323.78527583],
#        [324.03188828],
#        [324.28227024],
#        [324.52833209],
#        [324.77092093],
#        [325.01088384],
#        [325.25135498],
#        [325.49066846]])
